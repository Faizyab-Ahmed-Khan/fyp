# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

# Load the image
my_image = io.imread("cat.jpg")

# Display the image
plt.imshow(my_image)
plt.axis('off')  # Optional: turn off axis labels

# Show the plot
plt.show()

# %%
from skimage import io
import numpy as np
from matplotlib import pyplot as pit
from skimage import img_as_float
my_image=io.imread("cat.jpg")
#print (my_image)
print (my_image.min(),my_image.max())
my_float_image = img_as_float(my_image)
print (my_float_image.min(),my_float_image.max())

random_image = np.random.random([500,500] )
#pit.imshow(random_image)
#print(random_image)
print (random_image.min(),random_image.max())
# Out:
# 0 255
# 0.0 1.0
# 1.0933059338524842e-05 0.9999984272781556

# %%
from skimage import io
from skimage import img_as_float

# Load the image
my_image = io.imread("cat.jpg")

# Convert the image to float representation
my_float_image = img_as_float(my_image)

# Print the minimum and maximum values of the float image
print(my_float_image.min(), my_float_image.max())

dark_image
# Out:
# 0.0 1.0
