# %%
print("he")
# Out:
# he

# %%
# !pip install Pillow
# Out:
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB 187.9 kB/s eta 0:00:14
#     --------------------------------------- 0.0/2.6 MB 178.6 kB/s eta 0:00:15
#     --------------------------------------- 0.1/2.6 MB 252.2 kB/s eta 0:00:11
#    - -------------------------------------- 0.1/2.6 MB 309.1 kB/s eta 0:00:09
#    - -------------------------------------- 0.1/2.6 MB 361.0 kB/s eta 0:00:07
#    -- ------------------------------------- 0.2/2.6 MB 447.8 kB/s eta 0:00:06
#    --- ------------------------------------ 0.2/2.6 MB 504.4 kB/s eta 0:00:05
#    ---- ----------------------------------- 0.3/2.6 MB 565.1 kB/s eta 0:00:05
# ...

# %% [markdown]
# ENCODING

# %%
from PIL import Image

def encode_text(image_path, text, lsb):
    # Open the image
    image = Image.open(image_path)
    pixels = image.load()

    # Convert text to binary
    binary_text = ''.join(format(ord(char), '08b') for char in text)

    # Check if the image can hold the text
    max_chars = (image.size[0] * image.size[1] * lsb) // 8
    if len(binary_text) > max_chars:
        raise ValueError("Text is too long to be encoded in the image.")

    # Encode the text in the image
    char_index = 0
    for y in range(image.size[1]):
        for x in range(image.size[0]):
            r, g, b = pixels[x, y]

            # Modify the least significant bit of each color channel
            if char_index < len(binary_text):
                r = (r & ~(1 << lsb)) | (int(binary_text[char_index]) << lsb)
                char_index += 1
            if char_index < len(binary_text):
                g = (g & ~(1 << lsb)) | (int(binary_text[char_index]) << lsb)
                char_index += 1
            if char_index < len(binary_text):
                b = (b & ~(1 << lsb)) | (int(binary_text[char_index]) << lsb)
                char_index += 1

            pixels[x, y] = (r, g, b)

    # Save the modified image
    encoded_image_path = "encoded_image7.png"
    image.save(encoded_image_path)
    print("Text encoded successfully in the image:", encoded_image_path)

def decode_text(image_path, lsb):
    # Open the image
    image = Image.open(image_path)
    pixels = image.load()

    # Decode the text from the image
    binary_text = ""
    for y in range(image.size[1]):
        for x in range(image.size[0]):
            r, g, b = pixels[x, y]

            # Extract the least significant bit of each color channel
            binary_text += str((r >> lsb) & 1)
            binary_text += str((g >> lsb) & 1)
            binary_text += str((b >> lsb) & 1)

    # Convert binary text to ASCII
    decoded_text = ""
    for i in range(0, len(binary_text), 8):
        decoded_text += chr(int(binary_text[i:i+8], 2))

    return decoded_text

# Example usage
image_path = input("Enter the image location: ")
lsb = int(input("Enter the number of LSBs to use (1-8): "))
text = input("Enter the text to encode: ")

encode_text(image_path, text, lsb)

decoded_text = decode_text("encoded_image7.png", lsb)
print("Decoded text:", decoded_text)
# Out:
# Text encoded successfully in the image: encoded_image7.png
# ...

# %%
from PIL import Image

def decode_text(image_path, lsb):
    # Open the image
    image = Image.open(image_path)
    pixels = image.load()

    # Decode the text from the image
    binary_text = ""
    for y in range(image.size[1]):
        for x in range(image.size[0]):
            r, g, b = pixels[x, y]

            # Extract the least significant bit of each color channel
            binary_text += str((r >> lsb) & 1)
            binary_text += str((g >> lsb) & 1)
            binary_text += str((b >> lsb) & 1)

    # Convert binary text to ASCII
    decoded_text = ""
    for i in range(0, len(binary_text), 8):
        decoded_text += chr(int(binary_text[i:i+8], 2))

    return decoded_text

# Example usage
image_path = input("Enter the image location: ")
lsb = int(input("Enter the number of LSBs used during encoding (1-8): "))

decoded_text = decode_text(image_path, lsb)
print("Decoded text:", decoded_text)
# Out:
# Decoded text: Pillow is a Python Imaging Library (PIL), which adds image processing capabilities to your Python interpreter. You can use it to create, open, and manipulate images in a wide variety of formats.  Here are a few links where you can learn more about Pillow (PIL):  Pillow documentation: https://pillow.readthedocs.io/en/stable/ Pillow GitHub repository: https://github.com/python-pillow/Pillow If you have a specific code-related question about pip PIL, please provide more details so that I can assist you further.8 øàÀ{øñø?Àà=ÿøøàxÿÿøÀ?ÇÿÿÀþ@8GÿÿÀþÀÿÿþÿðÀÿÿþEÿÀÿÿÿ@ÿÿÀÿÿÿÿÀÿüÀÿÿÿÿÿÿàÀÿÿÿÿÿÿàþÿÿÿÿÿøÿÿþÿÿÿÿÿÀÿÿÿÐðÿÿÿÿÿèÿÿøÿþ/ÿÿÿÿÿÿÿÿøÿþ?ÿÿÿÿÿÿÿÿÏþþ?ÿÿÿÿþÿÿÏüI$?ÿÿÿÿÿÿÿÿÿÿÿþÐ@(Kd$ÿÿÿÿÿÿÿÿÿÿÿô@À	ÿÿ	/I ?ÿÿÿÿÿÿÿÿÿÿÿðP~KdÿÿþIÿH$Ûdÿÿÿÿÿÿÿÿÿÿÿÿ÷ÀüðÿþH¿ÿÿÿÿÿ¿É$ÿÿüÿÿÿÿÿÿÿÿÿÿÿÿÿÀôÿÿÿÿ$ÿÿÿÿÿÿÿûÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿE?à	I%ÿÿÿÿÿÿöI$$ÿÿÿÿÿÿÿÿÿÿÿÿð?ÿÿÿÿÿÿÿÿÿÿÿÿÿoø?	m_ä[ÿÿÿÿÿÿÿÛm¶@%ÿÿÿÿÿÿÿÿÿÿÿÿþ?ÿÿÿÿÿÿÿÿÿÿÿýÿýøÿKÿôüÿÿÿÿÿÿÿÿÿÿÿÿØ?ÿÿÿÿÿÿÿÿÿÿÿÿþ?ÿÿÿÿÿÿÿÿÿÿÿÿþÿøÿÀøOÿÿÐÿ²$¿ÿÿÿÿ
# ...

# %% [markdown]
# DECODING

# %%
def decode_text(image_path, lsb):
    # Open the image
    image = Image.open(image_path)
    pixels = image.load()

    # Decode the text from the image
    binary_text = ""
    for y in range(image.size[1]):
        for x in range(image.size[0]):
            r, g, b = pixels[x, y]

            # Extract the least significant bit of each color channel
            binary_text += str((r >> lsb) & 1)
            binary_text += str((g >> lsb) & 1)
            binary_text += str((b >> lsb) & 1)

    # Convert binary text to ASCII
    decoded_text = ""
    for i in range(0, len(binary_text), 8):
        decoded_text += chr(int(binary_text[i:i+8], 2))

    return decoded_text

# Example usage
image_path = input("Enter the image location: ")
lsb = int(input("Enter the number of LSBs used during encoding (1-8): "))

decoded_text = decode_text(image_path, lsb)
print("Decoded text:", decoded_text)

# Save the decoded text into a text file
output_file = "decoded_text.txt"
with open(output_file, "w", encoding="utf-8") as file:
    file.write(decoded_text)

print("Decoded text saved in:", output_file)
# Out:
# Decoded text: Pillow is a Python Imaging Library (PIL), which adds image processing capabilities to your Python interpreter. You can use it to create, open, and manipulate images in a wide variety of formats.  Here are a few links where you can learn more about Pillow (PIL):  Pillow documentation: https://pillow.readthedocs.io/en/stable/ Pillow GitHub repository: https://github.com/python-pillow/Pillow If you have a specific code-related question about pip PIL, please provide more details so that I can assist you further.8 øàÀ{øñø?Àà=ÿøøàxÿÿøÀ?ÇÿÿÀþ@8GÿÿÀþÀÿÿþÿðÀÿÿþEÿÀÿÿÿ@ÿÿÀÿÿÿÿÀÿüÀÿÿÿÿÿÿàÀÿÿÿÿÿÿàþÿÿÿÿÿøÿÿþÿÿÿÿÿÀÿÿÿÐðÿÿÿÿÿèÿÿøÿþ/ÿÿÿÿÿÿÿÿøÿþ?ÿÿÿÿÿÿÿÿÏþþ?ÿÿÿÿþÿÿÏüI$?ÿÿÿÿÿÿÿÿÿÿÿþÐ@(Kd$ÿÿÿÿÿÿÿÿÿÿÿô@À	ÿÿ	/I ?ÿÿÿÿÿÿÿÿÿÿÿðP~KdÿÿþIÿH$Ûdÿÿÿÿÿÿÿÿÿÿÿÿ÷ÀüðÿþH¿ÿÿÿÿÿ¿É$ÿÿüÿÿÿÿÿÿÿÿÿÿÿÿÿÀôÿÿÿÿ$ÿÿÿÿÿÿÿûÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿE?à	I%ÿÿÿÿÿÿöI$$ÿÿÿÿÿÿÿÿÿÿÿÿð?ÿÿÿÿÿÿÿÿÿÿÿÿÿoø?	m_ä[ÿÿÿÿÿÿÿÛm¶@%ÿÿÿÿÿÿÿÿÿÿÿÿþ?ÿÿÿÿÿÿÿÿÿÿÿýÿýøÿKÿôüÿÿÿÿÿÿÿÿÿÿÿÿØ?ÿÿÿÿÿÿÿÿÿÿÿÿþ?ÿÿÿÿÿÿÿÿÿÿÿÿþÿøÿÀøOÿÿÐÿ²$¿ÿÿÿÿ
# ...
